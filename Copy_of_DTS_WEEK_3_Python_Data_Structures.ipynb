# %% [markdown]
# <a href="https://colab.research.google.com/github/felindabitrus-arch/Felinda-/blob/Felindabitrus/Copy_of_DTS_WEEK_3_Python_Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ASSIGNMENT (Week 3)
#
# Submit your Jupyter Notebook (.ipynb) through your GitHub repository.

# %% [markdown]
# # ASSIGNMENT 1. Create a list of 5 student scores

# %%
scores = [60, 70, 65, 55, 90]
print(scores)
# Out:
# [60, 70, 65, 55, 90]

# %% [markdown]
# # ASSIGNMENT 2. Compute the average score

# %%
total = 0
for score in scores:
    total = total + score

average = total / len(scores)
print("Average score:", average)
# Out:
# Average score: 68.0

# %% [markdown]
# # ASSIGNMENT 3. Find the highest score

# %%
highest = scores[0]
for score in scores:
    if score > highest:
        highest = score

print("Highest score:", highest)
# Out:
# Highest score: 90

# %% [markdown]
# # ASSIGNMENT 4. Create a dictionary with 5 students and scores

# %%
student = {
    "name": "David",
    "math": 75,
    "english": 80,
    "science": 70
}

print(student)
print(student["math"])
# Out:
# {'name': 'David', 'math': 75, 'english': 80, 'science': 70}
# 75

# %%
student = {
    "name": "David",
    "math": 75,
    "english": 80,
    "science": 70
}

print(student)
print(student["math"])
# Out:
# {'name': 'David', 'math': 75, 'english': 80, 'science': 70}
# 75

# %% [markdown]
# # ASSIGNMENT 5. Find the highest scoring student

# %%
highest_id = None
highest_score = 0

for student_id in students:
    score = students[student_id]

    if score > highest_score:
        highest_score = score
        highest_id = student_id

print("Highest scoring student:", highest_id)
print("Score:", highest_score)
# Out:
# Highest scoring student: S004
# Score: 90

# %%
highest_id = None
highest_score = 0

for student_id in students:
    score = students[student_id]

    if score > highest_score:
        highest_score = score
        highest_id = student_id

print("Highest scoring student:", highest_id)
print("Score:", highest_score)
# Out:
# Highest scoring student: S004
# Score: 90

# %% [markdown]
# # ASSIGNMENT 6. Create a tuple of subjects

# %%
subjects = ("Math", "English", "Science")
print(subjects)
print(subjects[0])
# Out:
# ('Math', 'English', 'Science')
# Math

# %% [markdown]
# # ASSIGNMENT 7. Create a set of unique scores

# %%
scores_set = {60, 85, 75, 90}
print(scores_set)
# Out:
# {90, 75, 60, 85}

# %% [markdown]
# Good Job!

# %% [markdown]
#  Name Felinda Bitrus
#  Matric number uj/2025/cp/0258
