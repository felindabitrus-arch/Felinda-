# %% [markdown]
# <a href="https://colab.research.google.com/github/felindabitrus-arch/Felinda-/blob/Felindabitrus/WEEK_7_Basic_Charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 ASSIGNMENT (Week 7)
#
# 1. Create dataset with at least 10 students and 3 subjects.
# 2. Create line, bar, and pie charts.
# 3. Add titles and axis labels.
# 4. Write short interpretation.
#
# Submit your completed notebook (.ipynb).

# %%
students = ["Felinda", "Bobby", "Charles", "David", "John", "Faith", "Queen", "Samuel", "Grace", "Angel"]
math_scores = [65, 80, 45, 90, 75, 69, 90, 95, 70, 50]
english_scores = [70, 85, 50, 88, 80, 90, 70, 50, 75, 40]
chemistry_scores=[50, 69, 80, 40, 50, 70, 50, 90, 80, 39]

# %%
plt.figure()
plt.plot(students, math_scores)
plt.title("Math Scores - Line Chart")
plt.xlabel("Students")
plt.ylabel("Scores")
plt.show()

# %%
plt.figure()
plt.bar(students, math_scores)
plt.title("Math Scores - Bar Chart")
plt.xlabel("Students")
plt.ylabel("Scores")
plt.show()

# %%
plt.figure()
plt.pie(math_scores, labels=students, autopct='%1.1f%%')
plt.title("Math Score Distribution")
plt.show()

# %% [markdown]
# Line Chart
# The line chart shows variations in student performance across Mathematics, English, and Chemistry. Some students perform better in certain subjects, with Samuel and David showing strong overall performance.
# Bar Chart
# The bar chart compares each student's scores in the three subjects. It highlights that Samuel has the highest Mathematics score, while Faith performs best in English.
# Pie Chart
# The pie chart shows the proportion of scores among students in one subject. Students with higher scores take larger portions, while those with lower scores take smaller portions.

# %% [markdown]
# Felinda Bitrus UJ/2025/CP/0258
